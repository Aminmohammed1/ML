# %%
# !pip install pandas
import pandas as pd
import numpy as np

# %%
dframe = pd.DataFrame(np.random.randint(1, 30, size=(6,4)), columns = ['a', 'b', 'c', 'f'])
print(dframe)

print(dframe.set_index('a', inplace=True))
print(dframe)
dframe.dropna()
dframe.columns = ['A', 'B', 'C']
dframe['A' ] = dframe['A'].astype(float)
print(dframe)
dframe.sort_values()
# Out:
#     a   b   c   f
# 0  25  18  21  24
# 1  23   7  11   5
# 2  24  26   4  13
# 3  29  23   7  20
# 4  18   4  21  21
# 5  16  13   7  10
# None
#      b   c   f
# a
# 25  18  21  24
# 23   7  11   5
# 24  26   4  13
# 29  23   7  20
# 18   4  21  21
# 16  13   7  10
#        A   B   C
# a
# 25  18.0  21  24
# 23   7.0  11   5
# 24  26.0   4  13
# 29  23.0   7  20
# 18   4.0  21  21
# 16  13.0   7  10

# %% [markdown]
# _
