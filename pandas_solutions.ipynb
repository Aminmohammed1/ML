# %%
# !pip install pandas
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: pandas in ./numpypandasassignments/venv/lib/python3.12/site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in ./numpypandasassignments/venv/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./numpypandasassignments/venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./numpypandasassignments/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
dframe = pd.DataFrame(np.random.randint(1, 30, size=(6,4)), columns = ['a', 'b', 'c', 'f'])
print(dframe)

print(dframe.set_index('a', inplace=True))
print(dframe)
# Out:
#     a   b   c   f
# 0  10   9   5  11
# 1  16  17  25  15
# 2   3  10   3  14
# 3   7  28  27  24
# 4  23  29  22  11
# 5   2   6   7  20
# None
#      b   c   f
# a
# 10   9   5  11
# 16  17  25  15
# 3   10   3  14
# 7   28  27  24
# 23  29  22  11
# 2    6   7  20
